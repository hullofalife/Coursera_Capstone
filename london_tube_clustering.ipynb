# %%
#import libraries and packages 
import numpy as np 
import pandas as pd
! pip install folium==0.5.0
import folium # plotting library
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Out:
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)

# %%
#data setup
#scrub wiki page for tube stations with latitute and logtitude
url = 'https://wiki.openstreetmap.org/wiki/List_of_London_Underground_stations'
df_tube = pd.read_html(url)
df_tube=df_tube[0]
df_tube=df_tube[["Name","Latitude","Longitude","Line"]]
print(df_tube.head())
print(' ')
print(df_tube.shape)
print('')
print(df_tube.dtypes)
# Out:
#             Name     Latitude     Longitude                          Line
# 0     Acton Town    51.502500     -0.278126          District, Piccadilly
# 1  Acton Central  51.50883531  -0.263033174             London Overground
# 2  Acton Central  51.50856013  -0.262879534             London Overground
# 3        Aldgate     51.51394      -0.07537                  Metropolitan
# 4   Aldgate East     51.51514      -0.07178  District, Hammersmith & City
#
# (302, 4)
#
# Name         object
# Latitude     object
# Longitude    object
# Line         object
# dtype: object

# %%
df_tube["Longitude"] = df_tube.Longitude.replace('+',' ').apply(lambda x: x.split(' ')[0]).astype(float)
df_tube["Latitude"] = df_tube.Latitude.replace('+',' ').apply(lambda x: x.split(' ')[0]).astype(float)
df_tube.head()
# Out:
#             Name   Latitude  Longitude                          Line
# 0     Acton Town  51.502500  -0.278126          District, Piccadilly
# 1  Acton Central  51.508835  -0.263033             London Overground
# 2  Acton Central  51.508560  -0.262880             London Overground
# 3        Aldgate  51.513940  -0.075370                  Metropolitan
# 4   Aldgate East  51.515140  -0.071780  District, Hammersmith & City

# %%
# create map of London using latitude and longitude values
lat = 51.5074
long= -0.1278
map_london = folium.Map(location=[lat, long], zoom_start=10)

# add markers to map
for lat, lng, name, line in zip(df_tube['Latitude'], df_tube['Longitude'], df_tube['Name'], df_tube['Line']):
    label = '{}, {}'.format(name, line)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'V0CWQWNSAJ3NQVH4Q0ZAD5C0ERSEJPQ5JTGP53YQKFHFNQGO' # your Foursquare ID
CLIENT_SECRET = 'EFR1O5EROO0N0HWMDCF2PMEN3AHU0I4FSISISHU05N1UZGOT' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: V0CWQWNSAJ3NQVH4Q0ZAD5C0ERSEJPQ5JTGP53YQKFHFNQGO
# CLIENT_SECRET:EFR1O5EROO0N0HWMDCF2PMEN3AHU0I4FSISISHU05N1UZGOT

# %%
LIMIT = 1500 # limit of number of venues returned by Foursquare API

# define radius
# given that the venues should be walking distance from the tube stations
# set a radius of 500m 
# test various ones to see how it changes the clusters
radius = 500 


def getNearbyVenues(names, latitudes, longitudes, radius = 500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Tube', 
                  'Tube Latitude', 
                  'Tube Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here
london_venues = getNearbyVenues(names=df_tube['Name'],
                                   latitudes=df_tube['Latitude'],
                                   longitudes=df_tube['Longitude'],
                                  )
# Out:
# Acton Town
# Acton Central
# Acton Central
# Aldgate
# Aldgate East
# Alperton
# Amersham
# Angel
# Archway
# Arnos Grove
# Arsenal
# Baker Street
# Baker Street
# Balham
# Bank
# Barbican
# Barking
# Barkingside
# Barons Court
# Bayswater
# Becontree
# Belsize Park
# Bermondsey
# Bethnal Green
# Blackfriars
# Blackhorse Road
# Bond Street
# Borough
# Boston Manor
# Bounds Green
# Bow Road
# Brent Cross
# Brixton
# Bromley-by-Bow
# Brondesbury
# Brondesbury Park
# Buckhurst Hill
# Burnt Oak
# Caledonian Road
# Caledonian Road & Barnesbury
# Camden Road
# Camden Town
# Canada Water
# Canary Wharf
# Cannon Street
# Canonbury
# Canons Park
# Chalfont & Latimer
# Chalk Farm
# Chancery Lane
# Charing Cross
# Chesham
# Chigwell
# Chiswick Park
# Chorleywood
# City Thameslink
# Clapham Common
# Clapham North
# Clapham South
# Cockfosters
# Colindale
# Colliers Wood
# Covent Garden
# Croxley
# Dagenham East
# Dagenham Heathway
# Dalston Kingsland
# Debden
# Dollis Hill
# Ealing Broadway
# Ealing Common
# Earl's Court
# East Acton
# East Finchley
# East Ham
# East Putney
# Eastcote
# Edgware
# Edgware Road (Bakerloo Line)
# Edgware Road (Circle Line)
# Elephant & Castle
# Elm Park
# Embankment
# Epping
# Euston
# Euston Square
# Fairlop
# Farringdon
# Farringdon
# Finchley Central
# Finchley Road
# Finchley Road and Frognal
# Finsbury Park
# Fulham Broadway
# Gants Hill
# Gloucester Road
# Golders Green
# Goldhawk Road
# Goodge Street
# Gospel Oak
# Grange Hill
# Great Portland Street
# Greenford
# Gunnersbury
# Green Park
# Hackney Central
# Hackney Wick
# Hainault
# Hammersmith (Dist&Picc Line)
# Hammersmith (H&C Line)
# Hampstead
# Hampstead Heath
# Hanger Lane
# Harlesden
# Harrow & Wealdstone
# Harrow-on-the-Hill
# Hatton Cross
# Heathrow Terminals 1-2-3
# Heathrow Terminal 4
# Hendon Central
# High Barnet
# High Street Kensington
# Highbury & Islington
# Highgate
# Hillingdon
# Holborn
# Holland Park
# Holloway Road
# Homerton
# Hornchurch
# Hounslow Central
# Hounslow East
# Hounslow West
# Hyde Park Corner
# Ickenham
# Kennington
# Kensal Green
# Kensal Rise
# Kensington (Olympia)
# Kentish Town
# Kentish Town West
# Kenton
# Kew Gardens
# Kilburn
# Kilburn Park
# King's Cross St.Pancras
# King's Cross Thameslink
# Kingsbury
# Knightsbridge
# Ladbroke Grove
# Lambeth North
# Lancaster Gate
# Latimer Road
# Leicester Square
# Leyton
# Leytonstone
# Liverpool Street
# London Bridge
# Loughton
# Maida Vale
# Manor House
# Mansion House
# Marble Arch
# Marylebone
# Mile End
# Mill Hill East
# Monument
# Moor Park
# Moorgate
# Morden
# Mornington Crescent
# Neasden
# New Cross
# New Cross Gate
# Newbury Park
# North Acton
# North Ealing
# North Greenwich
# North Harrow
# North Wembley
# Northfields
# Northolt
# Northolt
# Northwick Park
# Northwood
# Northwood Hills
# Notting Hill Gate
# Oakwood
# Old Street
# Osterley
# Oval
# Oxford Circus
# Paddington
# Paddington (H&C Line)
# Park Royal
# Parsons Green
# Perivale
# Piccadilly Circus
# Pimlico
# Pinner
# Plaistow
# Preston Road
# Putney Bridge
# Queen's Park
# Queensbury
# Queensway
# Ravenscourt Park
# Rayners Lane
# Redbridge
# Regent's Park
# Richmond
# Richmond
# Rickmansworth
# Roding Valley
# Rotherhithe
# Royal Oak
# Ruislip
# Ruislip Gardens
# Ruislip Manor
# Russell Square
# St.James's Park
# Seven Sisters
# Shadwell
# Shepherd's Bush
# Shepherd's Bush Market
# Sloane Square
# Snaresbrook
# South Acton
# South Ealing
# South Harrow
# South Kensington
# South Kenton
# South Ruislip
# South Wimbledon
# South Woodford
# Southfields
# Southgate
# Southwark
# St.John's Wood
# St.Paul's
# Stamford Brook
# Stanmore
# Stepney Green
# Stockwell
# Stonebridge Park
# Stratford
# Stratford
# Sudbury Hill
# Sudbury Town
# Surrey Quays
# Swiss Cottage
# Temple
# Theydon Bois
# Tooting Bec
# Tooting Broadway
# Tottenham Court Road
# Tottenham Court Road
# Tottenham Hale
# Totteridge & Whetstone
# Tower Hill
# Tufnell Park
# Turnham Green
# Turnpike Lane
# Upminster
# Upminster Bridge
# Upney
# Upton Park
# Uxbridge
# Vauxhall
# Victoria
# Walthamstow Central
# Wanstead
# Wapping
# Warren Street
# Warwick Avenue
# Waterloo
# Watford
# Wembley Central
# Wembley Park
# West Acton
# West Brompton
# West Finchley
# West Ham
# West Hampstead
# West Hampstead
# West Hampstead
# West Hampstead
# West Harrow
# West Kensington
# West Ruislip
# Westbourne Park
# Westminster
# White City
# Whitechapel
# Willesden Green
# Willesden Junction
# Willesden Junction
# Wimbledon
# Wimbledon Park
# Wood Green
# Woodford
# Woodside Park

# %%
london_venues.head(6)
london_venues.size
# Out:
# 81844

# %%
london_restaurants = london_venues[london_venues['Venue Category'].str.contains("Restaurant")]

# %%
london_restaurants = london_restaurants[~london_restaurants['Venue Category'].str.contains("Italian")]

# %%
london_restaurants = london_restaurants.reset_index(drop=True)

# %%
london_restaurants.head()
# Out:
#             Tube  Tube Latitude  Tube Longitude                 Venue  \
# 0     Acton Town       51.50250       -0.278126         Crystal Kebab
# 1  Acton Central       51.50856       -0.262880     Rango'z Peri Peri
# 2        Aldgate       51.51394       -0.075370         Treves & Hyde
# 3        Aldgate       51.51394       -0.075370  The Japanese Canteen
# 4        Aldgate       51.51394       -0.075370                Hohaki
#
#    Venue Latitude  Venue Longitude         Venue Category
# 0       51.502917        -0.282631       Kebab Restaurant
# 1       51.506624        -0.256403   Fast Food Restaurant
# 2       51.514114        -0.070606             Restaurant
# 3       51.513775        -0.079079    Japanese Restaurant
# 4       51.516191        -0.076195  Vietnamese Restaurant

# %%
# some tube stations have a small number of restaurants close by
# the following code removes tube stations with less than 15 restaurants close by
london_restaurants = london_restaurants.groupby('Tube').filter(lambda x: len(x) > 10).reset_index(drop=True)
london_restaurants.head()
print('There are {} tube stations with more than 10 restaurants within 500m.'.format(len(london_restaurants['Tube'].unique())))
# Out:
# There are 86 tube stations with more than 10 restaurants within 500m.

# %%
london_restaurants.head()
# Out:
#       Tube  Tube Latitude  Tube Longitude                 Venue  \
# 0  Aldgate       51.51394        -0.07537         Treves & Hyde
# 1  Aldgate       51.51394        -0.07537  The Japanese Canteen
# 2  Aldgate       51.51394        -0.07537                Hohaki
# 3  Aldgate       51.51394        -0.07537      HELIX Restaurant
# 4  Aldgate       51.51394        -0.07537          My Old Place
#
#    Venue Latitude  Venue Longitude         Venue Category
# 0       51.514114        -0.070606             Restaurant
# 1       51.513775        -0.079079    Japanese Restaurant
# 2       51.516191        -0.076195  Vietnamese Restaurant
# 3       51.514488        -0.080360             Restaurant
# 4       51.516827        -0.076932    Szechuan Restaurant

# %%
print('There are {} uniques restaurant categories.'.format(len(london_restaurants['Venue Category'].unique())))
# Out:
# There are 80 uniques restaurant categories.

# %%
# one hot encoding
london_onehot = pd.get_dummies(london_restaurants[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
london_onehot['Tube'] = london_restaurants['Tube'] 

# move neighborhood column to the first column
fixed_columns = [london_onehot.columns[-1]] + list(london_onehot.columns[:-1])
london_onehot = london_onehot[fixed_columns]

#london_onehot.head()

# %%
london_grouped = london_onehot.groupby('Tube').mean().reset_index()

# %%
london_grouped.shape
# Out:
# (86, 81)

# %%
london_grouped.head(5)
# Out:
#            Tube  Afghan Restaurant  African Restaurant  American Restaurant  \
# 0       Aldgate           0.000000            0.033333             0.000000
# 1  Aldgate East           0.000000            0.000000             0.034483
# 2         Angel           0.047619            0.000000             0.000000
# 3  Baker Street           0.000000            0.000000             0.000000
# 4          Bank           0.000000            0.000000             0.000000
#
#    Arepa Restaurant  Argentinian Restaurant  Asian Restaurant  \
# 0               0.0                     0.0          0.066667
# 1               0.0                     0.0          0.034483
# 2               0.0                     0.0          0.000000
# 3               0.0                     0.0          0.000000
# 4               0.0                     0.0          0.038462
#
#    Australian Restaurant  Austrian Restaurant  Brazilian Restaurant  ...  \
# 0                    0.0             0.000000                   0.0  ...
# 1                    0.0             0.000000                   0.0  ...
# 2                    0.0             0.047619                   0.0  ...
# 3                    0.0             0.068966                   0.0  ...
# 4                    0.0             0.000000                   0.0  ...
#
#    Sushi Restaurant  Szechuan Restaurant  Taiwanese Restaurant  \
# 0          0.066667             0.033333                   0.0
# 1          0.034483             0.034483                   0.0
# 2          0.047619             0.000000                   0.0
# 3          0.000000             0.000000                   0.0
# 4          0.076923             0.000000                   0.0
#
#    Tapas Restaurant  Thai Restaurant  Turkish Restaurant  Udon Restaurant  \
# 0               0.0         0.066667            0.033333         0.000000
# 1               0.0         0.103448            0.068966         0.000000
# 2               0.0         0.000000            0.047619         0.000000
# 3               0.0         0.034483            0.068966         0.000000
# 4               0.0         0.000000            0.000000         0.038462
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Yoshoku Restaurant
# 0                       0.000000               0.066667                 0.0
# 1                       0.034483               0.068966                 0.0
# 2                       0.095238               0.095238                 0.0
# 3                       0.000000               0.000000                 0.0
# 4                       0.000000               0.153846                 0.0
#
# [5 rows x 81 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#pd.set_option('display.max_rows', None)
#print(london_restaurants)
#pd.set_option('display.max_columns', None)
#print(df.head())
#london_restaurants.head()

# %%
num_top_venues = 3

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Tube']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
tube_venues_sorted = pd.DataFrame(columns=columns)
tube_venues_sorted['Tube'] = london_grouped['Tube']

for ind in np.arange(london_grouped.shape[0]):
    tube_venues_sorted.iloc[ind, 1:] = return_most_common_venues(london_grouped.iloc[ind, :], num_top_venues)

tube_venues_sorted.head(30)
# Out:
#                             Tube          1st Most Common Venue  \
# 0                        Aldgate      Middle Eastern Restaurant
# 1                   Aldgate East              Indian Restaurant
# 2                          Angel              French Restaurant
# 3                   Baker Street                     Restaurant
# 4                           Bank                     Restaurant
# 5                       Barbican              French Restaurant
# 6                      Bayswater             Chinese Restaurant
# 7                    Blackfriars               Sushi Restaurant
# 8                    Bond Street              French Restaurant
# 9                        Borough         Argentinian Restaurant
# 10                       Brixton           Caribbean Restaurant
# 11                   Camden Road  Vegetarian / Vegan Restaurant
# 12                   Camden Town               Greek Restaurant
# 13                  Canary Wharf                     Restaurant
# 14                 Cannon Street             Seafood Restaurant
# 15                    Chalk Farm                     Restaurant
# 16                 Chancery Lane                     Restaurant
# 17                 Charing Cross                     Restaurant
# 18               City Thameslink             Falafel Restaurant
# 19                Clapham Common            Japanese Restaurant
# 20                 Clapham North            Japanese Restaurant
# 21                 Covent Garden              Indian Restaurant
# 22             Dalston Kingsland             Turkish Restaurant
# 23               Ealing Broadway                Thai Restaurant
# 24                  Earl's Court            Lebanese Restaurant
# 25  Edgware Road (Bakerloo Line)      Middle Eastern Restaurant
# 26    Edgware Road (Circle Line)      Middle Eastern Restaurant
# 27             Elephant & Castle      Latin American Restaurant
# 28                    Embankment                     Restaurant
# 29                 Euston Square              Indian Restaurant
#
#             2nd Most Common Venue      3rd Most Common Venue
# 0                      Restaurant          Indian Restaurant
# 1                 Thai Restaurant  Middle Eastern Restaurant
# 2   Vegetarian / Vegan Restaurant      Vietnamese Restaurant
# 3               French Restaurant         Chinese Restaurant
# 4           Vietnamese Restaurant         Seafood Restaurant
# 5           Vietnamese Restaurant         Turkish Restaurant
# 6              Persian Restaurant           Greek Restaurant
# 7              Falafel Restaurant                 Restaurant
# 8             Japanese Restaurant           Asian Restaurant
# 9           Portuguese Restaurant      Vietnamese Restaurant
# 10               Ramen Restaurant       Brazilian Restaurant
# 11               Greek Restaurant       Caribbean Restaurant
# 12  Vegetarian / Vegan Restaurant                 Restaurant
# 13              Indian Restaurant         Turkish Restaurant
# 14          Vietnamese Restaurant      Portuguese Restaurant
# 15              French Restaurant       Brazilian Restaurant
# 16          Vietnamese Restaurant          French Restaurant
# 17              French Restaurant         Mexican Restaurant
# 18                     Restaurant      Vietnamese Restaurant
# 19           Fast Food Restaurant         Turkish Restaurant
# 20          Portuguese Restaurant         Spanish Restaurant
# 21               Sushi Restaurant           Ramen Restaurant
# 22                     Restaurant       Caribbean Restaurant
# 23          Vietnamese Restaurant       Fast Food Restaurant
# 24                Thai Restaurant        Japanese Restaurant
# 25            Japanese Restaurant       Fast Food Restaurant
# 26            Japanese Restaurant           Tapas Restaurant
# 27             Chinese Restaurant       Cantonese Restaurant
# 28             Mexican Restaurant          French Restaurant
# 29               Sushi Restaurant         Mexican Restaurant

# %%
#tube_venues_sorted.head(100)

# %%
# set number of clusters
kclusters = 30

london_grouped_clustering = london_grouped.drop('Tube', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(london_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:100]
# Out:
# array([19,  3, 24,  4,  6,  9, 14, 11, 12, 20, 23,  1,  1, 11,  6, 11, 17,
#         0, 11, 11, 25, 24, 23, 11, 29,  7,  7, 15,  0,  3, 17,  3, 18, 12,
#        13,  8,  2,  3, 24, 11,  5,  5,  4, 24,  4, 27, 12, 10, 19, 19,  4,
#        24, 24, 12,  6, 12, 28,  6, 24,  1, 26, 19, 24, 19, 24, 21,  3,  0,
#        14,  8,  8,  4, 12, 11,  6, 16, 18,  3, 24, 19,  0, 11,  0,  3, 11,
#        22], dtype=int32)

# %%
tube_venues_sorted.head()
# Out:
#            Tube      1st Most Common Venue          2nd Most Common Venue  \
# 0       Aldgate  Middle Eastern Restaurant                     Restaurant
# 1  Aldgate East          Indian Restaurant                Thai Restaurant
# 2         Angel          French Restaurant  Vegetarian / Vegan Restaurant
# 3  Baker Street                 Restaurant              French Restaurant
# 4          Bank                 Restaurant          Vietnamese Restaurant
#
#        3rd Most Common Venue
# 0          Indian Restaurant
# 1  Middle Eastern Restaurant
# 2      Vietnamese Restaurant
# 3         Chinese Restaurant
# 4         Seafood Restaurant

# %%
df_tube.head()
# Out:
#             Name   Latitude  Longitude                          Line
# 0     Acton Town  51.502500  -0.278126          District, Piccadilly
# 1  Acton Central  51.508835  -0.263033             London Overground
# 2  Acton Central  51.508560  -0.262880             London Overground
# 3        Aldgate  51.513940  -0.075370                  Metropolitan
# 4   Aldgate East  51.515140  -0.071780  District, Hammersmith & City

# %%
# add clustering labels
tube_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

london_merged = df_tube
london_merged.rename(columns={"Name":"Tube"})
london_merged.head()
# Out:
#             Name   Latitude  Longitude                          Line
# 0     Acton Town  51.502500  -0.278126          District, Piccadilly
# 1  Acton Central  51.508835  -0.263033             London Overground
# 2  Acton Central  51.508560  -0.262880             London Overground
# 3        Aldgate  51.513940  -0.075370                  Metropolitan
# 4   Aldgate East  51.515140  -0.071780  District, Hammersmith & City

# %%
london_merged = london_merged.rename(columns={"Name":"Tube"})

# %%
# merge london_grouped with df_tube to add latitude/longitude for each Tube station
london_merged = london_merged.join(tube_venues_sorted.set_index('Tube'), on='Tube')

london_merged.head() # check the last columns!
# Out:
#             Tube   Latitude  Longitude                          Line  \
# 0     Acton Town  51.502500  -0.278126          District, Piccadilly
# 1  Acton Central  51.508835  -0.263033             London Overground
# 2  Acton Central  51.508560  -0.262880             London Overground
# 3        Aldgate  51.513940  -0.075370                  Metropolitan
# 4   Aldgate East  51.515140  -0.071780  District, Hammersmith & City
#
#    Cluster Labels      1st Most Common Venue 2nd Most Common Venue  \
# 0             NaN                        NaN                   NaN
# 1             NaN                        NaN                   NaN
# 2             NaN                        NaN                   NaN
# 3            19.0  Middle Eastern Restaurant            Restaurant
# 4             3.0          Indian Restaurant       Thai Restaurant
#
#        3rd Most Common Venue
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3          Indian Restaurant
# 4  Middle Eastern Restaurant

# %%
london_merged.dropna(inplace=True)

# %%
london_merged = london_merged.reset_index(drop=True)

# %%
london_merged.head()
# Out:
#            Tube   Latitude  Longitude                          Line  \
# 0       Aldgate  51.513940   -0.07537                  Metropolitan
# 1  Aldgate East  51.515140   -0.07178  District, Hammersmith & City
# 2         Angel  51.532530   -0.10579                      Northern
# 3  Baker Street  51.522650   -0.15704    Circle, Hammersmith & City
# 4  Baker Street  51.522236   -0.15708             Bakerloo, Jubilee
#
#    Cluster Labels      1st Most Common Venue          2nd Most Common Venue  \
# 0            19.0  Middle Eastern Restaurant                     Restaurant
# 1             3.0          Indian Restaurant                Thai Restaurant
# 2            24.0          French Restaurant  Vegetarian / Vegan Restaurant
# 3             4.0                 Restaurant              French Restaurant
# 4             4.0                 Restaurant              French Restaurant
#
#        3rd Most Common Venue
# 0          Indian Restaurant
# 1  Middle Eastern Restaurant
# 2      Vietnamese Restaurant
# 3         Chinese Restaurant
# 4         Chinese Restaurant

# %%
london_merged['Cluster Labels'] = london_merged['Cluster Labels'].astype(int)
london_merged.dtypes
# Out:
# Tube                      object
# Latitude                 float64
# Longitude                float64
# Line                      object
# Cluster Labels             int64
# 1st Most Common Venue     object
# 2nd Most Common Venue     object
# 3rd Most Common Venue     object
# dtype: object

# %%
# create map
map_clusters = folium.Map(location=[lat, long], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(london_merged['Latitude'], london_merged['Longitude'], london_merged['Tube'], london_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=15,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
london_merged.loc[london_merged['Cluster Labels'] == 0, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue 2nd Most Common Venue  \
# 18  Charing Cross            Restaurant     French Restaurant
# 29     Embankment            Restaurant    Mexican Restaurant
# 69       Richmond            Restaurant      Sushi Restaurant
# 70       Richmond            Restaurant      Sushi Restaurant
# 85       Victoria            Restaurant      Sushi Restaurant
# 87       Waterloo            Restaurant     Korean Restaurant
#
#     3rd Most Common Venue
# 18     Mexican Restaurant
# 29      French Restaurant
# 69        Thai Restaurant
# 70        Thai Restaurant
# 85  Portuguese Restaurant
# 87     Mexican Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 1, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                    Tube          1st Most Common Venue  \
# 12          Camden Road  Vegetarian / Vegan Restaurant
# 13          Camden Town               Greek Restaurant
# 61  Mornington Crescent               Greek Restaurant
#
#             2nd Most Common Venue 3rd Most Common Venue
# 12               Greek Restaurant  Caribbean Restaurant
# 13  Vegetarian / Vegan Restaurant            Restaurant
# 61            Japanese Restaurant            Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 2, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube    1st Most Common Venue 2nd Most Common Venue  \
# 38  Goodge Street  Scandinavian Restaurant      Greek Restaurant
#
#    3rd Most Common Venue
# 38   Japanese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 3, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                      Tube  1st Most Common Venue    2nd Most Common Venue  \
# 1            Aldgate East      Indian Restaurant          Thai Restaurant
# 30          Euston Square      Indian Restaurant         Sushi Restaurant
# 33       Finchley Central      Indian Restaurant       Turkish Restaurant
# 39  Great Portland Street  Vietnamese Restaurant        Indian Restaurant
# 68       Ravenscourt Park      Indian Restaurant      Japanese Restaurant
# 81       Tooting Broadway      Indian Restaurant  South Indian Restaurant
# 88         West Hampstead      Indian Restaurant    Vietnamese Restaurant
# 89         West Hampstead      Indian Restaurant    Vietnamese Restaurant
# 90         West Hampstead      Indian Restaurant    Vietnamese Restaurant
# 91         West Hampstead      Indian Restaurant    Vietnamese Restaurant
#
#         3rd Most Common Venue
# 1   Middle Eastern Restaurant
# 30         Mexican Restaurant
# 33        Japanese Restaurant
# 39       Brazilian Restaurant
# 68         Chinese Restaurant
# 81            Thai Restaurant
# 88            Thai Restaurant
# 89            Thai Restaurant
# 90            Thai Restaurant
# 91            Thai Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 4, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                       Tube 1st Most Common Venue 2nd Most Common Venue  \
# 3             Baker Street            Restaurant     French Restaurant
# 4             Baker Street            Restaurant     French Restaurant
# 44  High Street Kensington            Restaurant    Chinese Restaurant
# 46                 Holborn    Chinese Restaurant            Restaurant
# 52          Lancaster Gate            Restaurant     Indian Restaurant
# 74           Sloane Square     French Restaurant            Restaurant
#
#    3rd Most Common Venue
# 3     Chinese Restaurant
# 4     Chinese Restaurant
# 44     Indian Restaurant
# 46   Japanese Restaurant
# 52     French Restaurant
# 74     Indian Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 5, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                             Tube          1st Most Common Venue  \
# 42  Hammersmith (Dist&Picc Line)             Turkish Restaurant
# 43        Hammersmith (H&C Line)  Vegetarian / Vegan Restaurant
#
#     2nd Most Common Venue 3rd Most Common Venue
# 42        Thai Restaurant   Japanese Restaurant
# 43  Portuguese Restaurant      Tapas Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 6, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube       1st Most Common Venue       2nd Most Common Venue  \
# 5            Bank                  Restaurant       Vietnamese Restaurant
# 15  Cannon Street          Seafood Restaurant       Vietnamese Restaurant
# 56  Mansion House          Seafood Restaurant  Modern European Restaurant
# 59       Monument                  Restaurant        Fast Food Restaurant
# 77      St.Paul's  Modern European Restaurant                  Restaurant
#
#     3rd Most Common Venue
# 5      Seafood Restaurant
# 15  Portuguese Restaurant
# 56       Asian Restaurant
# 59     Seafood Restaurant
# 77  Vietnamese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 7, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                             Tube      1st Most Common Venue  \
# 26  Edgware Road (Bakerloo Line)  Middle Eastern Restaurant
# 27    Edgware Road (Circle Line)  Middle Eastern Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue
# 26   Japanese Restaurant  Fast Food Restaurant
# 27   Japanese Restaurant      Tapas Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 8, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                       Tube      1st Most Common Venue  \
# 37           Goldhawk Road  Middle Eastern Restaurant
# 72         Shepherd's Bush         Chinese Restaurant
# 73  Shepherd's Bush Market         Chinese Restaurant
#
#         2nd Most Common Venue 3rd Most Common Venue
# 37            Thai Restaurant    Falafel Restaurant
# 72       Fast Food Restaurant       Thai Restaurant
# 73  Middle Eastern Restaurant    Falafel Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 9, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#        Tube 1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue
# 6  Barbican     French Restaurant  Vietnamese Restaurant    Turkish Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 10, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                     Tube 1st Most Common Venue 2nd Most Common Venue  \
# 49  Kensington (Olympia)    Persian Restaurant     Indian Restaurant
#
#    3rd Most Common Venue
# 49            Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 11, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                Tube       1st Most Common Venue  2nd Most Common Venue  \
# 8       Blackfriars            Sushi Restaurant     Falafel Restaurant
# 14     Canary Wharf                  Restaurant      Indian Restaurant
# 16       Chalk Farm                  Restaurant      French Restaurant
# 19  City Thameslink          Falafel Restaurant             Restaurant
# 20   Clapham Common         Japanese Restaurant   Fast Food Restaurant
# 24  Ealing Broadway             Thai Restaurant  Vietnamese Restaurant
# 41  Hackney Central  Modern European Restaurant   Fast Food Restaurant
# 76        Southwark            Ramen Restaurant       Asian Restaurant
# 86    Warren Street           Indian Restaurant             Restaurant
# 92        Wimbledon            Sushi Restaurant             Restaurant
#
#         3rd Most Common Venue
# 8                  Restaurant
# 14         Turkish Restaurant
# 16       Brazilian Restaurant
# 19      Vietnamese Restaurant
# 20         Turkish Restaurant
# 24       Fast Food Restaurant
# 41         Turkish Restaurant
# 76         Seafood Restaurant
# 86  Middle Eastern Restaurant
# 92          Indian Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 12, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                 Tube      1st Most Common Venue      2nd Most Common Venue  \
# 9        Bond Street          French Restaurant        Japanese Restaurant
# 35   Gloucester Road          French Restaurant     Argentinian Restaurant
# 48  Hyde Park Corner  Middle Eastern Restaurant          French Restaurant
# 55     London Bridge                 Restaurant         Seafood Restaurant
# 57       Marble Arch        Lebanese Restaurant  Middle Eastern Restaurant
# 75  South Kensington          French Restaurant     Argentinian Restaurant
#
#    3rd Most Common Venue
# 9       Asian Restaurant
# 35    Seafood Restaurant
# 48            Restaurant
# 55     French Restaurant
# 57     French Restaurant
# 75    Seafood Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 13, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue 2nd Most Common Venue  \
# 36  Golders Green     Korean Restaurant    Turkish Restaurant
#
#    3rd Most Common Venue
# 36      Sushi Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 14, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#          Tube 1st Most Common Venue 2nd Most Common Venue  \
# 7   Bayswater    Chinese Restaurant    Persian Restaurant
# 71  Royal Oak    Persian Restaurant     Indian Restaurant
#
#    3rd Most Common Venue
# 7       Greek Restaurant
# 71            Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 15, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                  Tube      1st Most Common Venue 2nd Most Common Venue  \
# 28  Elephant & Castle  Latin American Restaurant    Chinese Restaurant
#
#    3rd Most Common Venue
# 28  Cantonese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 16, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#          Tube 1st Most Common Venue      2nd Most Common Venue  \
# 78  Stratford  Fast Food Restaurant  Latin American Restaurant
# 79  Stratford  Fast Food Restaurant  Latin American Restaurant
#
#    3rd Most Common Venue
# 78      Doner Restaurant
# 79      Doner Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 17, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue  2nd Most Common Venue  \
# 17  Chancery Lane            Restaurant  Vietnamese Restaurant
# 31     Farringdon    Falafel Restaurant      French Restaurant
# 32     Farringdon    Falafel Restaurant      French Restaurant
#
#     3rd Most Common Venue
# 17      French Restaurant
# 31  Vietnamese Restaurant
# 32  Vietnamese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 18, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue 2nd Most Common Venue  \
# 34  Finchley Road   Japanese Restaurant      Asian Restaurant
# 80  Swiss Cottage   Japanese Restaurant    Chinese Restaurant
#
#    3rd Most Common Venue
# 34    Chinese Restaurant
# 80  Cantonese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 19, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube      1st Most Common Venue  2nd Most Common Venue  \
# 0         Aldgate  Middle Eastern Restaurant             Restaurant
# 50   Kentish Town          French Restaurant             Restaurant
# 51  Knightsbridge                 Restaurant      French Restaurant
# 63     Old Street      Vietnamese Restaurant    Japanese Restaurant
# 65     Paddington           Greek Restaurant      French Restaurant
# 84  Turnham Green                 Restaurant  Vietnamese Restaurant
#
#         3rd Most Common Venue
# 0           Indian Restaurant
# 50           Malay Restaurant
# 51  Middle Eastern Restaurant
# 63           Ramen Restaurant
# 65  Middle Eastern Restaurant
# 84        Japanese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 20, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#        Tube   1st Most Common Venue  2nd Most Common Venue  \
# 10  Borough  Argentinian Restaurant  Portuguese Restaurant
#
#     3rd Most Common Venue
# 10  Vietnamese Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 21, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#          Tube 1st Most Common Venue 2nd Most Common Venue  \
# 67  Queensway    Chinese Restaurant      Greek Restaurant
#
#    3rd Most Common Venue
# 67            Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 22, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#           Tube 1st Most Common Venue 2nd Most Common Venue  \
# 93  Wood Green  Fast Food Restaurant    Turkish Restaurant
#
#        3rd Most Common Venue
# 93  Mediterranean Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 23, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                  Tube 1st Most Common Venue 2nd Most Common Venue  \
# 11            Brixton  Caribbean Restaurant      Ramen Restaurant
# 23  Dalston Kingsland    Turkish Restaurant            Restaurant
#
#    3rd Most Common Venue
# 11  Brazilian Restaurant
# 23  Caribbean Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 24, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                     Tube      1st Most Common Venue  \
# 2                  Angel          French Restaurant
# 22         Covent Garden          Indian Restaurant
# 40            Green Park          Indian Restaurant
# 45  Highbury & Islington  Middle Eastern Restaurant
# 53      Leicester Square           Sushi Restaurant
# 54      Liverpool Street          Indian Restaurant
# 60              Moorgate           Asian Restaurant
# 64         Oxford Circus          Indian Restaurant
# 66     Piccadilly Circus         Seafood Restaurant
# 82  Tottenham Court Road           Sushi Restaurant
# 83  Tottenham Court Road           Sushi Restaurant
#
#             2nd Most Common Venue      3rd Most Common Venue
# 2   Vegetarian / Vegan Restaurant      Vietnamese Restaurant
# 22               Sushi Restaurant           Ramen Restaurant
# 40             Seafood Restaurant                 Restaurant
# 45              Indian Restaurant          French Restaurant
# 53             Seafood Restaurant        Japanese Restaurant
# 54       Mediterranean Restaurant  Middle Eastern Restaurant
# 60      Latin American Restaurant  South American Restaurant
# 64              French Restaurant         English Restaurant
# 66               Tapas Restaurant      Portuguese Restaurant
# 82               Ramen Restaurant   Mediterranean Restaurant
# 83               Ramen Restaurant   Mediterranean Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 25, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue  2nd Most Common Venue  \
# 21  Clapham North   Japanese Restaurant  Portuguese Restaurant
#
#    3rd Most Common Venue
# 21    Spanish Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 26, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#                Tube 1st Most Common Venue 2nd Most Common Venue  \
# 62  North Greenwich   American Restaurant  Brazilian Restaurant
#
#         3rd Most Common Venue
# 62  Latin American Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 27, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#              Tube 1st Most Common Venue      2nd Most Common Venue  \
# 47  Holloway Road  Ethiopian Restaurant  Latin American Restaurant
#
#    3rd Most Common Venue
# 47    Shaanxi Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 28, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#           Tube 1st Most Common Venue 2nd Most Common Venue  \
# 58  Marylebone   Japanese Restaurant       Thai Restaurant
#
#    3rd Most Common Venue
# 58            Restaurant

# %%
london_merged.loc[london_merged['Cluster Labels'] == 29, london_merged.columns[[0] + list(range(5, london_merged.shape[1]))]]
# Out:
#             Tube 1st Most Common Venue 2nd Most Common Venue  \
# 25  Earl's Court   Lebanese Restaurant       Thai Restaurant
#
#    3rd Most Common Venue
# 25   Japanese Restaurant

# %%
#THINGS TO IMPROVE
#REMOVE DUPLICATE TUBE STATIONS
#REMOVE PLACES THAT YOU WOULDN'T VISIT AS A TOURIST SUCH AS SUPERMARKET, GROCERY, BUS STOP, METRO STATION, 
# remove tube stations with less then 5 restaurants
